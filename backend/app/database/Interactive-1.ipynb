# %% [markdown]
# Connected to document-copilot-backend (3.14.5) (Python 3.14.5)

# %%
supabase_url: str

# %%
settings = Settings()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 settings = Settings()
#
# NameError: name 'Settings' is not defined

# %%
from typing import Annotated

# %%
settings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 settings
#
# NameError: name 'settings' is not defined

# %%
settings = Settings()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 settings = Settings()
#
# NameError: name 'Settings' is not defined

# %%
settings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 settings
#
# NameError: name 'settings' is not defined
